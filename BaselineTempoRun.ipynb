# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/TempoRun2025/dataset.zip
# Out:
# Archive:  /content/drive/MyDrive/TempoRun2025/dataset.zip
#    creating: dataset/
#    creating: dataset/public/
#   inflating: dataset/public/105a4de8.json
#   inflating: dataset/public/1a150873.json
#   inflating: dataset/public/c5087e0f.json
#   inflating: dataset/public/dce587aa.json
#   inflating: dataset/public/d6110501.json
#   inflating: dataset/public/eceac1a3.json
#   inflating: dataset/public/27d7feb8.json
#   inflating: dataset/public/0dc43831.json
#   inflating: dataset/public/669891d0.json
#   inflating: dataset/public/9c4ba5ca.json
#   inflating: dataset/public/18539150.json
#   inflating: dataset/public/471aaf0c.json
#   inflating: dataset/public/7b90e8a1.json
#   inflating: dataset/public/9ada8586.json
#   inflating: dataset/public/af40fa87.json
#   inflating: dataset/public/2edcf272.json
#   inflating: dataset/public/7f4e9e97.json
#   inflating: dataset/public/73743c6c.json
#   inflating: dataset/public/fa3593f3.json
#   inflating: dataset/public/a2aa2f73.json
#   inflating: dataset/public/798044b8.json
#   inflating: dataset/public/75f4426b.json
#   inflating: dataset/public/f3cdfbcb.json
#   inflating: dataset/public/df4ac5a4.json
#   inflating: dataset/public/9a02b459.json
#   inflating: dataset/public/c59a37d2.json
#   inflating: dataset/public/27646201.json
#   inflating: dataset/public/6e36c3e4.json
#   inflating: dataset/public/ac618fc7.json
#   inflating: dataset/public/3bebf631.json
#   inflating: dataset/public/fe519c8b.json
#   inflating: dataset/public/41120091.json
#   inflating: dataset/public/c807df79.json
#   inflating: dataset/public/f3a61dd2.json
#   inflating: dataset/public/f408cc57.json
#   inflating: dataset/public/c3eba516.json
#   inflating: dataset/public/e034cdc8.json
#   inflating: dataset/public/8d774e12.json
#   inflating: dataset/public/6843027b.json
#   inflating: dataset/public/ba55f7a9.json
#   inflating: dataset/public/bd681b8c.json
#   inflating: dataset/public/b4888c6b.json
#   inflating: dataset/public/4a8e3e79.json
#   inflating: dataset/public/47e272ec.json
#   inflating: dataset/public/3969f494.json
#   inflating: dataset/public/5c3756f9.json
#   inflating: dataset/public/a700ffb2.json
#   inflating: dataset/public/298b9090.json
#   inflating: dataset/public/796d3748.json
#   inflating: dataset/public/96932e05.json
#   inflating: dataset/public/ddd68614.json
#   inflating: dataset/public/9683061a.json
#   inflating: dataset/public/a825bbdc.json
#   inflating: dataset/public/32d5609f.json
#   inflating: dataset/public/c370fa72.json
#   inflating: dataset/public/0164aa98.json
#   inflating: dataset/public/d970e95f.json
#   inflating: dataset/public/e9fcae5a.json
#   inflating: dataset/public/468e5895.json
#   inflating: dataset/public/7a0774d6.json
#   inflating: dataset/public/09d3547a.json
#   inflating: dataset/public/d75eb9bb.json
#   inflating: dataset/public/fbcc9808.json
#   inflating: dataset/public/ac5bc40b.json
#   inflating: dataset/public/28d377e7.json
#   inflating: dataset/public/021140a6.json
#   inflating: dataset/public/35cc752f.json
#   inflating: dataset/public/136c2427.json
#   inflating: dataset/public/cb25a531.json
#   inflating: dataset/public/a6bf7013.json
#   inflating: dataset/public/b8eef123.json
#   inflating: dataset/public/f8512507.json
#   inflating: dataset/private/287ede8c.json
#   inflating: dataset/private/8eb1667d.json
#   inflating: dataset/private/e032e673.json
#   inflating: dataset/private/9243b78f.json
#   inflating: dataset/private/489e09fb.json
#   inflating: dataset/private/4c9888ce.json
#   inflating: dataset/private/18c67e3e.json
#   inflating: dataset/private/019aeed2.json
#   inflating: dataset/private/c90968a7.json
#   inflating: dataset/private/5b9acdad.json
#   inflating: dataset/private/9e65809b.json
#   inflating: dataset/private/f2e0037b.json
#   inflating: dataset/private/deeb3b89.json
#   inflating: dataset/private/12ca4685.json
#   inflating: dataset/private/7abc11f9.json
#   inflating: dataset/private/20c5f081.json
#   inflating: dataset/private/ce60fce4.json
#   inflating: dataset/private/68e2b7b7.json
#   inflating: dataset/private/71b89445.json
#   inflating: dataset/private/9758befc.json
#   inflating: dataset/private/ec30611a.json
#   inflating: dataset/private/4938c201.json
#   inflating: dataset/private/ca45252e.json
#   inflating: dataset/private/57ce2ef4.json
#   inflating: dataset/private/d152ecc1.json
#   inflating: dataset/private/3c7fe2aa.json
#   inflating: dataset/private/996a9db8.json
#   inflating: dataset/private/80aa3293.json
#   inflating: dataset/private/06afff77.json
#   inflating: dataset/private/037a7868.json
#   inflating: dataset/private/9ab57dc5.json
#   inflating: dataset/private/9768529f.json
#   inflating: dataset/private/0220be76.json
#   inflating: dataset/private/4be1d28f.json
#   inflating: dataset/private/4205eaba.json
#   inflating: dataset/private/7d11f960.json
#   inflating: dataset/private/893ce3ac.json
#   inflating: dataset/private/f95730d9.json
#   inflating: dataset/private/6eabd3f0.json
#   inflating: dataset/private/eb1db6d9.json
#   inflating: dataset/private/48be7cc1.json
#   inflating: dataset/private/3baa15a2.json
#   inflating: dataset/private/8cd9ba8f.json
#   inflating: dataset/private/04a97e2e.json
#   inflating: dataset/private/79f26b2f.json
#   inflating: dataset/private/cf8ae349.json
#   inflating: dataset/private/e53949a6.json
#   inflating: dataset/private/6176c441.json
#   inflating: dataset/private/79997919.json
#   inflating: dataset/private/4c15df65.json
#   inflating: dataset/private/bfc7f340.json
#   inflating: dataset/private/408ff027.json
#   inflating: dataset/private/a2997baf.json
#   inflating: dataset/private/0eca8ecd.json
#   inflating: dataset/private/9d186bad.json
#   inflating: dataset/private/78cafea9.json
#   inflating: dataset/private/2486de19.json
#   inflating: dataset/private/dcda969a.json
#   inflating: dataset/private/2a6313ee.json
#   inflating: dataset/private/1ccc5670.json
#   inflating: dataset/private/a19dd41d.json
#   inflating: dataset/private/cac2d435.json
#   inflating: dataset/private/617a7fb3.json
#   inflating: dataset/private/9a662dd7.json
#   inflating: dataset/private/2729ba5c.json
#   inflating: dataset/private/40349130.json
#   inflating: dataset/private/e24e742e.json
#   inflating: dataset/private/c9285109.json
#   inflating: dataset/private/48af025f.json
#   inflating: dataset/private/bc4829b7.json
#   inflating: dataset/private/ae9cecee.json
#   inflating: dataset/private/3d3e007a.json
#   inflating: dataset/private/9328e73a.json
#   inflating: dataset/private/9359d592.json
#   inflating: dataset/private/6b382d2f.json
#   inflating: dataset/private/9eaf03e4.json
#   inflating: dataset/private/f7cfbedc.json
#   inflating: dataset/private/97198ca4.json
#   inflating: dataset/private/f2edcf79.json
#   inflating: dataset/private/9dfb3629.json
#   inflating: dataset/private/f91f50f0.json
#   inflating: dataset/private/33a9794b.json
#   inflating: dataset/private/9e604b54.json
#   inflating: dataset/private/8e568eb5.json
#   inflating: dataset/private/fa1da10d.json
#   inflating: dataset/private/28b786be.json
#   inflating: dataset/private/99fc46b8.json
#   inflating: dataset/private/b989d758.json
#   inflating: dataset/private/0a6988f9.json
#   inflating: dataset/private/75973a6f.json
#   inflating: dataset/private/1d984877.json
#   inflating: dataset/private/2234f8e6.json
#   inflating: dataset/private/1da05f5c.json
#   inflating: dataset/private/b5c2c1fb.json
#   inflating: dataset/private/7ce42bfc.json
#   inflating: dataset/private/26cb4f9c.json
#   inflating: dataset/private/6f2e5d52.json
#   inflating: dataset/private/6794e7e1.json
#   inflating: dataset/private/0efe772f.json
#   inflating: dataset/private/2cd62b94.json
#   inflating: dataset/private/9e646240.json
#   inflating: dataset/private/4ba1e657.json
#   inflating: dataset/private/db79e181.json
#   inflating: dataset/private/7755a777.json
#   inflating: dataset/private/b0d055c5.json
#   inflating: dataset/private/a17703b1.json
#   inflating: dataset/private/b65df90d.json
#   inflating: dataset/private/c6562450.json
#   inflating: dataset/private/3b3db524.json
#   inflating: dataset/private/ea611eb2.json
#   inflating: dataset/private/720d3187.json
#   inflating: dataset/private/fe020ba8.json
#   inflating: dataset/private/8c52b594.json
#   inflating: dataset/private/6941d4b9.json
#   inflating: dataset/private/2f2128ad.json
#   inflating: dataset/private/80a30327.json
#   inflating: dataset/private/6a826180.json
#   inflating: dataset/private/c34ce60c.json
#   inflating: dataset/private/df19734e.json
#   inflating: dataset/private/7cc7efeb.json
#   inflating: dataset/private/292a1109.json
#   inflating: dataset/private/57c51ecd.json
#   inflating: dataset/private/5bd9ecbb.json
#   inflating: dataset/private/9e848744.json
#   inflating: dataset/private/223565c1.json
#   inflating: dataset/private/aace7bd9.json
#   inflating: dataset/private/72d3d6e0.json
#   inflating: dataset/private/e45507b8.json
#   inflating: dataset/private/aae6d439.json
#   inflating: dataset/private/d9cc4ae0.json
#   inflating: dataset/private/321cdd98.json
#   inflating: dataset/private/e363409e.json
#   inflating: dataset/private/e8ab47fd.json
#   inflating: dataset/private/7bd7676e.json
#   inflating: dataset/private/40938daf.json
#   inflating: dataset/private/43fb8d2f.json
#   inflating: dataset/private/393571df.json
#   inflating: dataset/private/60d7ac06.json
#   inflating: dataset/private/dd7a426e.json
#   inflating: dataset/private/33df3775.json
#   inflating: dataset/private/d0f9e35d.json
#   inflating: dataset/private/47c7c927.json
#   inflating: dataset/private/b733353e.json
#   inflating: dataset/private/e020e2e8.json
#   inflating: dataset/private/69866751.json
#   inflating: dataset/private/9febcc26.json
#   inflating: dataset/private/df48fbf2.json
#   inflating: dataset/private/5f9ff24c.json
#   inflating: dataset/private/ce4f4c93.json
#   inflating: dataset/private/c8640ef3.json
#   inflating: dataset/private/aed01423.json
#   inflating: dataset/private/69b2d566.json
#   inflating: dataset/private/ffca3e37.json
#   inflating: dataset/private/6e763df2.json
#   inflating: dataset/private/dc0fa3e7.json
#   inflating: dataset/private/7e2ec9be.json
#   inflating: dataset/private/729ac857.json
#   inflating: dataset/private/8dcfffc1.json
#   inflating: dataset/private/6587eb97.json
#   inflating: dataset/private/2cc91c50.json
#   inflating: dataset/private/6c4eb408.json
#   inflating: dataset/private/791c9a19.json
#   inflating: dataset/private/c7e5ad1e.json
#   inflating: dataset/private/d5d09169.json
#   inflating: dataset/private/cf686bd9.json
#   inflating: dataset/private/c9768280.json
#   inflating: dataset/private/e5222d9f.json
#   inflating: dataset/private/06c385d5.json
#   inflating: dataset/private/cc444dbd.json
#   inflating: dataset/private/e8e9e501.json
#   inflating: dataset/private/fd61e3df.json
#   inflating: dataset/private/33d33f69.json
#   inflating: dataset/private/222f48cb.json
#   inflating: dataset/private/d6896d44.json
#   inflating: dataset/private/b984e06e.json
#   inflating: dataset/private/245c4e7c.json
#   inflating: dataset/private/ec1df4fb.json
#   inflating: dataset/private/cdd5918d.json
#   inflating: dataset/private/25a12065.json
#   inflating: dataset/private/86ebf87e.json
#   inflating: dataset/private/7fb4419b.json
#   inflating: dataset/private/c3b5639a.json
#   inflating: dataset/private/67475bfb.json
#   inflating: dataset/private/6bface6b.json
#   inflating: dataset/private/877ab0e0.json
#   inflating: dataset/private/6f54c4c8.json
#   inflating: dataset/private/f5059651.json
#   inflating: dataset/private/f74422b8.json
#   inflating: dataset/private/a1fb40a1.json
#   inflating: dataset/private/5e5ece82.json
#   inflating: dataset/private/cdb90e99.json
#   inflating: dataset/private/51a818ac.json
#   inflating: dataset/private/d85ff22e.json
#   inflating: dataset/private/3c7fa79c.json
#   inflating: dataset/private/ea3a5603.json
#   inflating: dataset/private/58f3253c.json
#   inflating: dataset/private/8b3e5814.json
#   inflating: dataset/private/2e4318bc.json
#   inflating: dataset/private/c56c7f83.json
#   inflating: dataset/private/901f403c.json
#   inflating: dataset/private/8c32cac5.json
#   inflating: dataset/private/61e1fe76.json
#   inflating: dataset/private/0d96643d.json
#   inflating: dataset/private/206d4a0e.json
#   inflating: dataset/private/fcc005a5.json
#   inflating: dataset/private/b1b4f890.json
#   inflating: dataset/private/2bada23a.json
#   inflating: dataset/private/0586636f.json
#   inflating: dataset/private/51e54de7.json
#   inflating: dataset/private/25692dce.json
#   inflating: dataset/private/db0d4e75.json
#   inflating: dataset/private/71a790c7.json
#   inflating: dataset/private/d6858b25.json
#   inflating: dataset/private/e2b9562c.json
#   inflating: dataset/private/167e7ce8.json
#   inflating: dataset/private/63a81b03.json
#   inflating: dataset/private/0a6f38d8.json
#   inflating: dataset/private/55657b41.json
#   inflating: dataset/private/268873fc.json
#   inflating: dataset/private/f0db615a.json
#   inflating: dataset/private/61784438.json
#   inflating: dataset/private/6d029dba.json
#   inflating: dataset/private/db844e5f.json
#   inflating: dataset/private/760c5045.json
#   inflating: dataset/private/8ce7d760.json
#   inflating: dataset/private/a6e1353d.json
#   inflating: dataset/private/1b132154.json
#   inflating: dataset/private/c7815363.json
#   inflating: dataset/private/8da5891f.json
#   inflating: dataset/private/28388165.json
#   inflating: dataset/private/360a3710.json
#   inflating: dataset/private/c7aebc82.json
#   inflating: dataset/private/0243130e.json
#   inflating: dataset/private/0bdb3dbf.json
#   inflating: dataset/private/8292f6cd.json
#   inflating: dataset/private/82d75cce.json
#   inflating: dataset/private/7647fb93.json
#   inflating: dataset/private/501855b6.json
#   inflating: dataset/private/2bacadfa.json
#   inflating: dataset/private/ff226697.json
#   inflating: dataset/private/10d5cbe9.json
#   inflating: dataset/private/34660370.json
#   inflating: dataset/private/af5685d2.json
#   inflating: dataset/private/30d2da04.json
#   inflating: dataset/private/89cc9bcd.json
#   inflating: dataset/private/2c72907b.json
#   inflating: dataset/private/6ba001b3.json
#   inflating: dataset/private/48f64bc7.json
#   inflating: dataset/private/bc8e9281.json
#   inflating: dataset/private/a5e3133e.json
#   inflating: dataset/private/60b00e37.json
#   inflating: dataset/private/8242a568.json
#   inflating: dataset/private/439aabde.json
#   inflating: dataset/private/d4566a2a.json
#   inflating: dataset/private/0a50818f.json
#   inflating: dataset/private/2f8ac1ac.json
#   inflating: dataset/private/d3cbb3b1.json
#   inflating: dataset/private/db5bdffe.json
#   inflating: dataset/private/ab351917.json
#   inflating: dataset/private/1c51f74f.json
#   inflating: dataset/private/6a89f6cf.json
#   inflating: dataset/private/50f7135a.json
#   inflating: dataset/private/2f4d7b37.json
#   inflating: dataset/private/f2d4fe6e.json
#   inflating: dataset/private/4053f32c.json
#   inflating: dataset/private/895bdeda.json
#   inflating: dataset/private/1ae91c3a.json
#   inflating: dataset/private/20a52501.json
#   inflating: dataset/private/eee55c88.json
#   inflating: dataset/private/bcbe0102.json
#   inflating: dataset/private/56b57078.json
#   inflating: dataset/private/5e77ffab.json
#   inflating: dataset/private/ccaeb179.json
#   inflating: dataset/private/71895cc7.json
#   inflating: dataset/private/29f1dd4a.json
#   inflating: dataset/private/a83fe447.json
#   inflating: dataset/private/c30eec97.json
#   inflating: dataset/private/aad8c60a.json
#   inflating: dataset/private/11e7378d.json
#    creating: dataset/train/
#   inflating: dataset/train/b27174da.json
#   inflating: dataset/train/3e04d97d.json
#   inflating: dataset/train/1b048e9a.json
#   inflating: dataset/train/53cbf5ed.json
#   inflating: dataset/train/9eb38605.json
#   inflating: dataset/train/bd4633c1.json
#   inflating: dataset/train/8f97c260.json
#   inflating: dataset/train/7aca3966.json
#   inflating: dataset/train/801fe8ff.json
#   inflating: dataset/train/7ab61133.json
#   inflating: dataset/train/b570fabd.json
#   inflating: dataset/train/4d172de6.json
#   inflating: dataset/train/4723b271.json
#   inflating: dataset/train/2a655567.json
#   inflating: dataset/train/60b80202.json
#   inflating: dataset/train/bbe54d1a.json
#   inflating: dataset/train/de72e134.json
#   inflating: dataset/train/b6942d63.json
#   inflating: dataset/train/8e40e61c.json
#   inflating: dataset/train/deadefab.json
#   inflating: dataset/train/a1c6af70.json
#   inflating: dataset/train/8f73c9f9.json
#   inflating: dataset/train/6e2dc0af.json
#   inflating: dataset/train/b1be61c8.json
#   inflating: dataset/train/1f5968d7.json
#   inflating: dataset/train/3b155998.json
#   inflating: dataset/train/7bf774b8.json
#   inflating: dataset/train/053d1ae4.json
#   inflating: dataset/train/abd80fb1.json
#   inflating: dataset/train/a44080a3.json
#   inflating: dataset/train/2086f141.json
#   inflating: dataset/train/79a21d60.json
#   inflating: dataset/train/5e777f2d.json
#   inflating: dataset/train/6ab6a04f.json
#   inflating: dataset/train/ccc22f1c.json
#   inflating: dataset/train/2f2e8fa9.json
#   inflating: dataset/train/783fc7ed.json
#   inflating: dataset/train/87ccde45.json
#   inflating: dataset/train/72b619dc.json
#   inflating: dataset/train/cf8f809c.json
#   inflating: dataset/train/c3deb351.json
#   inflating: dataset/train/d1b4b41a.json
#   inflating: dataset/train/a17988f2.json
#   inflating: dataset/train/fc4a6a39.json
#   inflating: dataset/train/9f7fbfe7.json
#   inflating: dataset/train/a9126125.json
#   inflating: dataset/train/51cdacf0.json
#   inflating: dataset/train/cdb93ace.json
#   inflating: dataset/train/beba2d30.json
#   inflating: dataset/train/bb514596.json
#   inflating: dataset/train/03edbf1f.json
#   inflating: dataset/train/cca013e3.json
#   inflating: dataset/train/1e10ef4d.json
#   inflating: dataset/train/fe9d79bf.json
#   inflating: dataset/train/eb89f20f.json
#   inflating: dataset/train/509a25c4.json
#   inflating: dataset/train/1bc53d7c.json
#   inflating: dataset/train/86565e20.json
#   inflating: dataset/train/9bbcf4a9.json
#   inflating: dataset/train/e1d58efb.json
#   inflating: dataset/train/8a4bf5d3.json
#   inflating: dataset/train/38b742c6.json
#   inflating: dataset/train/67632343.json
#   inflating: dataset/train/f6d1945b.json
#   inflating: dataset/train/6c527162.json
#   inflating: dataset/train/927cb770.json
#   inflating: dataset/train/2267c350.json
#   inflating: dataset/train/6adcd2b0.json
#   inflating: dataset/train/670399c7.json
#   inflating: dataset/train/d921e3ee.json
#   inflating: dataset/train/e148f36b.json
#   inflating: dataset/train/86bc1733.json
#   inflating: dataset/train/6a0d4d9e.json
#   inflating: dataset/train/62ea7c7b.json
#   inflating: dataset/train/ce357eec.json
#   inflating: dataset/train/26e0b26e.json
#   inflating: dataset/train/eef89e19.json
#   inflating: dataset/train/5831cf25.json
#   inflating: dataset/train/eba3c79a.json
#   inflating: dataset/train/7f4aef8c.json
#   inflating: dataset/train/e32e7c1a.json
#   inflating: dataset/train/fe86830c.json
#   inflating: dataset/train/529bf856.json
#   inflating: dataset/train/fc3437cc.json
#   inflating: dataset/train/1cf2775a.json
#   inflating: dataset/train/e8bf09e2.json
#   inflating: dataset/train/99fff90a.json
#   inflating: dataset/train/de0cc29e.json
#   inflating: dataset/train/175ca744.json
#   inflating: dataset/train/12eaae9c.json
#   inflating: dataset/train/e92d09d6.json
#   inflating: dataset/train/51f5de38.json
#   inflating: dataset/train/efb835f4.json
#   inflating: dataset/train/3543a56e.json
#   inflating: dataset/train/8794a5ce.json
#   inflating: dataset/train/354a9d58.json
#   inflating: dataset/train/a7e6899e.json
#   inflating: dataset/train/94deb272.json
#   inflating: dataset/train/da0af843.json
#   inflating: dataset/train/c5a86162.json
#   inflating: dataset/train/0d1f4ce8.json
#   inflating: dataset/train/e2d60bf4.json
#   inflating: dataset/train/5502f39f.json
#   inflating: dataset/train/ec6548b3.json
#   inflating: dataset/train/d948b008.json
#   inflating: dataset/train/b77215b6.json
#   inflating: dataset/train/f3b588a9.json
#   inflating: dataset/train/5855761a.json
#   inflating: dataset/train/3912046c.json
#   inflating: dataset/train/c96bcb61.json
#   inflating: dataset/train/097218d0.json
#   inflating: dataset/train/4ac32d61.json
#   inflating: dataset/train/8bb6fa3a.json
#   inflating: dataset/train/2195eec3.json
#   inflating: dataset/train/685690ef.json
#   inflating: dataset/train/a93feb40.json
#   inflating: dataset/train/3a2b6331.json
#   inflating: dataset/train/794b23b3.json
#   inflating: dataset/train/1f0764e8.json
#   inflating: dataset/train/a356772d.json
#   inflating: dataset/train/b855f777.json
#   inflating: dataset/train/84c8f132.json
#   inflating: dataset/train/fc99f9d3.json
#   inflating: dataset/train/81a40a3a.json
#   inflating: dataset/train/2cc45d32.json
#   inflating: dataset/train/8086817c.json
#   inflating: dataset/train/12a61b06.json
#   inflating: dataset/train/3b6646da.json
#   inflating: dataset/train/54c66f07.json
#   inflating: dataset/train/c23e6e53.json
#   inflating: dataset/train/6f199c1e.json
#   inflating: dataset/train/5760df3f.json
#   inflating: dataset/train/be4f54a2.json
#   inflating: dataset/train/ed396dda.json
#   inflating: dataset/train/685b7c5f.json
#   inflating: dataset/train/ed4bfce0.json
#   inflating: dataset/train/f82d298b.json
#   inflating: dataset/train/d30efc00.json
#   inflating: dataset/train/5b9e1f08.json
#   inflating: dataset/train/fa413f32.json
#   inflating: dataset/train/eaaaa691.json
#   inflating: dataset/train/ef79929a.json
#   inflating: dataset/train/5711204a.json
#   inflating: dataset/train/a7156b57.json
#   inflating: dataset/train/7e0d30be.json
#   inflating: dataset/train/21a198e4.json
#   inflating: dataset/train/b1c15bda.json
#   inflating: dataset/train/6c399151.json
#   inflating: dataset/train/bce012e3.json
#   inflating: dataset/train/2291f8a7.json
#   inflating: dataset/train/54e76a8e.json
#   inflating: dataset/train/6629a510.json
#   inflating: dataset/train/dc3ee960.json
#   inflating: dataset/train/f142cc36.json
#   inflating: dataset/train/f949ea1a.json
#   inflating: dataset/train/bbe597e6.json
#   inflating: dataset/train/a38e190e.json
#   inflating: dataset/train/aa27f057.json
#   inflating: dataset/train/5d8f64fe.json
#   inflating: dataset/train/a0c3dd93.json
#   inflating: dataset/train/21a4d3d1.json
#   inflating: dataset/train/49d215e4.json
#   inflating: dataset/train/b730dc2c.json
#   inflating: dataset/train/c7ab25cb.json
#   inflating: dataset/train/f07ec0c8.json
#   inflating: dataset/train/f5f5507d.json
#   inflating: dataset/train/408d3245.json
#   inflating: dataset/train/52dccdaf.json
#   inflating: dataset/train/e6c67046.json
#   inflating: dataset/train/4da52071.json
#   inflating: dataset/train/769c7162.json
#   inflating: dataset/train/a25eff67.json
#   inflating: dataset/train/3f7e677e.json
#   inflating: dataset/train/64b7f532.json
#   inflating: dataset/train/0694a5e6.json
#   inflating: dataset/train/d745604f.json
#   inflating: dataset/train/872664a4.json
#   inflating: dataset/train/e630300a.json
#   inflating: dataset/train/e1cffb4d.json
#   inflating: dataset/train/4a948f68.json
#   inflating: dataset/train/81b69d79.json
#   inflating: dataset/train/82c35a64.json
#   inflating: dataset/train/8b464412.json
#   inflating: dataset/train/d872bcd3.json
#   inflating: dataset/train/b61798da.json
#   inflating: dataset/train/f28eded4.json
#   inflating: dataset/train/f744bcb3.json
#   inflating: dataset/train/ea53ea74.json
#   inflating: dataset/train/d453250c.json
#   inflating: dataset/train/cd2a46a9.json
#   inflating: dataset/train/7314f4c8.json
#   inflating: dataset/train/ee53b5ab.json
#   inflating: dataset/train/0a7b828a.json
#   inflating: dataset/train/b1829ab7.json
#   inflating: dataset/train/1aec35b2.json
#   inflating: dataset/train/b78d41ff.json
#   inflating: dataset/train/64a2e772.json
#   inflating: dataset/train/3f53ad12.json
#   inflating: dataset/train/a5db8141.json
#   inflating: dataset/train/5eae362b.json
#   inflating: dataset/train/ac65bfcd.json
#   inflating: dataset/train/fdb714bf.json
#   inflating: dataset/train/c0d58e08.json
#   inflating: dataset/train/b7255cf0.json
#   inflating: dataset/train/a047cc08.json
#   inflating: dataset/train/23015d08.json
#   inflating: dataset/train/aa9d5448.json
#   inflating: dataset/train/40ea89fc.json
#   inflating: dataset/train/c7d820c0.json
#   inflating: dataset/train/2df12d54.json
#   inflating: dataset/train/ada9238b.json
#   inflating: dataset/train/1e910de0.json
#   inflating: dataset/train/2fdab20f.json
#   inflating: dataset/train/2ab2d56b.json
#   inflating: dataset/train/da07c429.json
#   inflating: dataset/train/212a3d76.json
#   inflating: dataset/train/b8d14ced.json
#   inflating: dataset/train/08141fbe.json
#   inflating: dataset/train/55a11ef8.json
#   inflating: dataset/train/25c44c55.json
#   inflating: dataset/train/3426585c.json
#   inflating: dataset/train/2cf80d54.json
#   inflating: dataset/train/18e3f34e.json
#   inflating: dataset/train/9d23242d.json
#   inflating: dataset/train/dfe78187.json
#   inflating: dataset/train/a265a648.json
#   inflating: dataset/train/b6f89eb0.json
#   inflating: dataset/train/937393be.json
#   inflating: dataset/train/2bd0922b.json
#   inflating: dataset/train/dabe459d.json
#   inflating: dataset/train/23e42818.json
#   inflating: dataset/train/77659d3d.json
#   inflating: dataset/train/abe690f7.json
#   inflating: dataset/train/9ecc52eb.json
#   inflating: dataset/train/7e30bc13.json
#   inflating: dataset/train/94442ddb.json
#   inflating: dataset/train/f9048aa6.json
#   inflating: dataset/train/00bc6000.json
#   inflating: dataset/train/4eea0e3d.json
#   inflating: dataset/train/6606dfeb.json
#   inflating: dataset/train/77711ec6.json
#   inflating: dataset/train/adb8aaec.json
#   inflating: dataset/train/7e0391ab.json
#   inflating: dataset/train/ad65b8ea.json
#   inflating: dataset/train/2ca0d982.json
#   inflating: dataset/train/78fd39c1.json
#   inflating: dataset/train/e35f3b24.json
#   inflating: dataset/train/633b474c.json
#   inflating: dataset/train/c9db0572.json
#   inflating: dataset/train/732c42f6.json
#   inflating: dataset/train/7f5eaf84.json
#   inflating: dataset/train/bed518c4.json
#   inflating: dataset/train/e512685b.json
#   inflating: dataset/train/e18f0c45.json
#   inflating: dataset/train/4d5a49c1.json
#   inflating: dataset/train/d433732c.json
#   inflating: dataset/train/b610e1cf.json
#   inflating: dataset/train/b88e0be4.json
#   inflating: dataset/train/2baa7e51.json
#   inflating: dataset/train/e788cd0e.json
#   inflating: dataset/train/cc890a05.json
#   inflating: dataset/train/edce3536.json
#   inflating: dataset/train/5f0cafad.json
#   inflating: dataset/train/8b237ecd.json
#   inflating: dataset/train/286c143c.json
#   inflating: dataset/train/15013add.json
#   inflating: dataset/train/baccae74.json
#   inflating: dataset/train/9b660dda.json
#   inflating: dataset/train/6e2feac1.json
#   inflating: dataset/train/049f7c00.json
#   inflating: dataset/train/152e6e47.json
#   inflating: dataset/train/3ba21cff.json
#   inflating: dataset/train/98c21b56.json
#   inflating: dataset/train/d69f77e8.json
#   inflating: dataset/train/180c81b7.json
#   inflating: dataset/train/c7a75aed.json
#   inflating: dataset/train/9e9f78aa.json
#   inflating: dataset/train/4867dd74.json
#   inflating: dataset/train/fda3975a.json
#   inflating: dataset/train/caedd1b5.json
#   inflating: dataset/train/de2ee7c9.json
#   inflating: dataset/train/740e04ac.json
#   inflating: dataset/train/ab01cc51.json
#   inflating: dataset/train/33751cc7.json
#   inflating: dataset/train/a1e0a69f.json
#   inflating: dataset/train/278b6e54.json
#   inflating: dataset/train/f011b35c.json
#   inflating: dataset/train/e0aab077.json
#   inflating: dataset/train/57ba661d.json
#   inflating: dataset/train/a12bcef7.json
#   inflating: dataset/train/5395da3b.json
#   inflating: dataset/train/0d58a299.json
#   inflating: dataset/train/f6a40cf1.json
#   inflating: dataset/train/0e52dbce.json
#   inflating: dataset/train/e794d852.json
#   inflating: dataset/train/0488b112.json
#   inflating: dataset/train/0db44f26.json
#   inflating: dataset/train/a3c84b4a.json
#   inflating: dataset/train/dc4cf7de.json
#   inflating: dataset/train/b65edc17.json
#   inflating: dataset/train/23ffebe8.json
#   inflating: dataset/train/3a9cfb68.json
#   inflating: dataset/train/535483f9.json
#   inflating: dataset/train/772e1fb1.json
#   inflating: dataset/train/1586fa6a.json
#   inflating: dataset/train/017d49eb.json
#   inflating: dataset/train/85606f60.json
#   inflating: dataset/train/d9c513ed.json
#   inflating: dataset/train/f8fac31e.json
#   inflating: dataset/train/6f313794.json
#   inflating: dataset/train/774db4f9.json
#   inflating: dataset/train/824544a5.json
#   inflating: dataset/train/c3d579ea.json
#   inflating: dataset/train/ca471a95.json
#   inflating: dataset/train/34d99639.json
#   inflating: dataset/train/fb19c3bc.json
#   inflating: dataset/train/a21987a0.json
#   inflating: dataset/train/645e6c5e.json
#   inflating: dataset/train/0d2de101.json
#   inflating: dataset/train/eeef3086.json
#   inflating: dataset/train/0cc3ba96.json
#   inflating: dataset/train/5feccf1d.json
#   inflating: dataset/train/10f662af.json
#   inflating: dataset/train/110ca90f.json
#   inflating: dataset/train/3dee62a1.json
#   inflating: dataset/train/7be27e1d.json
#   inflating: dataset/train/33be7f8b.json
#   inflating: dataset/train/ed04b14b.json
#   inflating: dataset/train/ba90f3c9.json
#   inflating: dataset/train/36a9cdda.json
#   inflating: dataset/train/5eefe5fd.json
#   inflating: dataset/train/dc58fba2.json
#   inflating: dataset/train/7220dc71.json
#   inflating: dataset/train/ee4499c9.json
#   inflating: dataset/train/a64dd68b.json
#   inflating: dataset/train/96650b71.json
#   inflating: dataset/train/8b65009c.json
#   inflating: dataset/train/c58ca51a.json
#   inflating: dataset/train/65c439be.json
#   inflating: dataset/train/ea31f2c6.json
#   inflating: dataset/train/33c2beb2.json
#   inflating: dataset/train/db988ad0.json
#   inflating: dataset/train/18a1f713.json
#   inflating: dataset/train/e0106506.json
#   inflating: dataset/train/0d1f13f9.json
#   inflating: dataset/train/140754a8.json
#   inflating: dataset/train/a20b01b8.json
#   inflating: dataset/train/72475b9c.json
#   inflating: dataset/train/2ffc84a2.json
#   inflating: dataset/train/353b8513.json
#   inflating: dataset/train/a0af08fc.json
#   inflating: dataset/train/65620ba5.json
#   inflating: dataset/train/1d188562.json
#   inflating: dataset/train/53b78c01.json
#   inflating: dataset/train/5a60281a.json
#   inflating: dataset/train/4a3975cd.json
#   inflating: dataset/train/21cf4709.json
#   inflating: dataset/train/03a32fa2.json
#   inflating: dataset/train/c7f69d22.json
#   inflating: dataset/train/48971f23.json
#   inflating: dataset/train/97a1a08f.json
#   inflating: dataset/train/8f6922ed.json
#   inflating: dataset/train/962f48dd.json
#   inflating: dataset/train/38d25c38.json
#   inflating: dataset/train/d3fd3ba4.json
#   inflating: dataset/train/b720def6.json
#   inflating: dataset/train/60f0bafb.json
#   inflating: dataset/train/e2f51958.json
#   inflating: dataset/train/745558c2.json
#   inflating: dataset/train/35d4d04e.json
#   inflating: dataset/train/94a60a84.json
#   inflating: dataset/train/86b7a6bb.json
#   inflating: dataset/train/2e6a0f98.json
#   inflating: dataset/train/0056adec.json
#   inflating: dataset/train/a16714f4.json
#   inflating: dataset/train/87485174.json
#   inflating: dataset/train/513466a6.json
#   inflating: dataset/train/7969a174.json
#   inflating: dataset/train/9a150b94.json
#   inflating: dataset/train/8901b805.json
#   inflating: dataset/train/7281f2de.json
#   inflating: dataset/train/b750f870.json
#   inflating: dataset/train/2806e2c1.json
#   inflating: dataset/train/6ea73d57.json
#   inflating: dataset/train/0992dd3b.json
#   inflating: dataset/train/0cf8aa62.json
#   inflating: dataset/train/70161c31.json
#   inflating: dataset/train/b4dcca40.json
#   inflating: dataset/train/1f5a87de.json
#   inflating: dataset/train/ba766cdf.json
#   inflating: dataset/train/3679d0c5.json
#   inflating: dataset/train/fd9436dd.json
#   inflating: dataset/train/3d6915df.json
#   inflating: dataset/train/3bc5dd8e.json
#   inflating: dataset/train/e8542898.json
#   inflating: dataset/train/a53fdd3c.json
#   inflating: dataset/train/7cd46f4a.json
#   inflating: dataset/train/8102ed3d.json
#   inflating: dataset/train/38087290.json
#   inflating: dataset/train/b3ad1a1b.json
#   inflating: dataset/train/0d6efee5.json
#   inflating: dataset/train/080faab2.json
#   inflating: dataset/train/469ce15d.json
#   inflating: dataset/train/cc640202.json
#   inflating: dataset/train/a8dfc249.json
#   inflating: dataset/train/02e0ee0a.json
#   inflating: dataset/train/05670bba.json
#   inflating: dataset/train/2708296e.json
#   inflating: dataset/train/4a60c1f5.json
#   inflating: dataset/train/9ef509ae.json
#   inflating: dataset/train/1270dcb7.json
#   inflating: dataset/train/12c38c8b.json
#   inflating: dataset/train/7a5128d5.json
#   inflating: dataset/train/151cd528.json
#   inflating: dataset/train/093381ff.json
#   inflating: dataset/train/65b6b0ea.json
#   inflating: dataset/train/de7929f9.json
#   inflating: dataset/train/8e4b8bcb.json
#   inflating: dataset/train/b124a1dc.json
#   inflating: dataset/train/2469ca0d.json
#   inflating: dataset/train/9d7a26c3.json
#   inflating: dataset/train/7ef7d37e.json
#   inflating: dataset/train/8f15c679.json
#   inflating: dataset/train/607b2036.json
#   inflating: dataset/train/a2c6d986.json
#   inflating: dataset/train/f67691b1.json
#   inflating: dataset/train/1bc20c91.json
#   inflating: dataset/train/0faf6db4.json
#   inflating: dataset/train/e0659931.json
#   inflating: dataset/train/0a87c8ed.json
#   inflating: dataset/train/c120ac8e.json
#   inflating: dataset/train/b34d0a15.json
#   inflating: dataset/train/cd99a902.json
#   inflating: dataset/train/d97a1d9d.json
#   inflating: dataset/train/a979d1db.json
#   inflating: dataset/train/bab6620e.json
#   inflating: dataset/train/191519a0.json
#   inflating: dataset/train/2d24c18c.json
#   inflating: dataset/train/3cc3e5f4.json
#   inflating: dataset/train/dd092b21.json
#   inflating: dataset/train/a80fc89a.json
#   inflating: dataset/train/4a249d56.json
# ...
#   inflating: dataset/train/9c9f87b3.json
#   inflating: dataset/train/abb09d91.json
#   inflating: dataset/train/4c2e8cca.json
#   inflating: dataset/train/4391683a.json
#   inflating: dataset/train/b2591095.json
#   inflating: dataset/train/89699993.json
#   inflating: dataset/train/f8254521.json
#   inflating: dataset/train/23864458.json
#   inflating: dataset/train/94eb12cc.json
#   inflating: dataset/train/e4c4e3fc.json
#   inflating: dataset/train/c8e86ee4.json
#   inflating: dataset/train/fedec612.json
#   inflating: dataset/train/4e1e1801.json
#   inflating: dataset/train/c8c6f1e6.json
#   inflating: dataset/train/332f82ba.json
#   inflating: dataset/train/8d1a48ad.json
#   inflating: dataset/train/e3d93072.json
#   inflating: dataset/train/964e3b82.json
#   inflating: dataset/train/27f4f52c.json
#   inflating: dataset/train/1a6f84ee.json
#   inflating: dataset/train/d017c012.json
#   inflating: dataset/train/2d86af38.json
#   inflating: dataset/train/900f5c72.json
#   inflating: dataset/train/9c0a7e49.json
#   inflating: dataset/train/862730e9.json
#   inflating: dataset/train/49d636af.json
#   inflating: dataset/train/161a9db6.json
#   inflating: dataset/train/85d8c60e.json
#   inflating: dataset/train/1678f3e0.json
#   inflating: dataset/train/1328db62.json
#   inflating: dataset/train/57700692.json
#   inflating: dataset/train/5aeb1c98.json
#   inflating: dataset/train/db797762.json
#   inflating: dataset/train/8d890e47.json
#   inflating: dataset/train/e70391c8.json
#   inflating: dataset/train/b6dc8d71.json
#   inflating: dataset/train/43bb1ccc.json
#   inflating: dataset/train/ffad429d.json
#   inflating: dataset/train/00f81aaf.json
#   inflating: dataset/train/b11f3ac8.json
#   inflating: dataset/train/cf600b65.json
#   inflating: dataset/train/da8d4053.json
#   inflating: dataset/train/e45f677d.json
#   inflating: dataset/train/0e198ac1.json
#   inflating: dataset/train/6e875cf9.json
#   inflating: dataset/train/9c1b288e.json
#   inflating: dataset/train/24c9c4cf.json
#   inflating: dataset/train/50ee2386.json
#   inflating: dataset/train/1b44baee.json
#   inflating: dataset/train/985b0922.json
#   inflating: dataset/train/3e09eefe.json
#   inflating: dataset/train/7d5f6faf.json
#   inflating: dataset/train/c7e2d191.json
#   inflating: dataset/train/1d284f3b.json
#   inflating: dataset/train/721a6f82.json
#   inflating: dataset/train/4d8f7b62.json
#   inflating: dataset/train/adeacbdf.json
#   inflating: dataset/train/0623b8d9.json
#   inflating: dataset/train/dfdb61e4.json
#   inflating: dataset/train/28af29b0.json
#   inflating: dataset/train/393a15a8.json
#   inflating: dataset/train/0a3e4a42.json
#   inflating: dataset/train/ac8dc91d.json
#   inflating: dataset/train/a4cb7ab3.json
#   inflating: dataset/train/525fa9b4.json
#   inflating: dataset/train/bc3d8c4a.json
#   inflating: dataset/train/1832fa1a.json
#   inflating: dataset/train/0cad6a7b.json
#   inflating: dataset/train/ee88178c.json
#   inflating: dataset/train/19beef31.json
#   inflating: dataset/train/bda0058e.json
#   inflating: dataset/train/0f64d61d.json
#   inflating: dataset/train/78fe7f4b.json
#   inflating: dataset/train/2a7c1199.json
#   inflating: dataset/train/41c8637c.json
#   inflating: dataset/train/edaafc63.json
#   inflating: dataset/train/593bd2bb.json
#   inflating: dataset/train/a9725df3.json
#   inflating: dataset/train/644acf52.json
#   inflating: dataset/train/08755f8a.json
#   inflating: dataset/train/c61e9dc4.json
#   inflating: dataset/train/cd35f91c.json
#   inflating: dataset/train/5a66971a.json
#   inflating: dataset/train/4b7d7f3e.json
#   inflating: dataset/train/29705bfc.json
#   inflating: dataset/train/83ab2e20.json
#   inflating: dataset/train/36a0a7b5.json
#   inflating: dataset/train/1421ad05.json
#   inflating: dataset/train/10deb3a1.json
#   inflating: dataset/train/44a686f7.json
#   inflating: dataset/train/7c9ca380.json
#   inflating: dataset/train/1900a272.json
#   inflating: dataset/train/b86b039e.json
#   inflating: dataset/train/a6f5d673.json
#   inflating: dataset/train/b1363541.json
#   inflating: dataset/train/47fdd90f.json
#   inflating: dataset/train/b8f98103.json
#   inflating: dataset/train/bc95f9be.json
#   inflating: dataset/train/6caefc94.json
#   inflating: dataset/train/be040ad1.json
#   inflating: dataset/train/72cd0577.json
#   inflating: dataset/train/5dc6286b.json
#   inflating: dataset/train/8052ac30.json
#   inflating: dataset/train/3a9145f1.json
#   inflating: dataset/train/94934402.json
#   inflating: dataset/train/9bf54699.json
#   inflating: dataset/train/10ae03ca.json
#   inflating: dataset/train/4678f2be.json
#   inflating: dataset/train/8d9a02c7.json
#   inflating: dataset/train/d3f43a66.json
#   inflating: dataset/train/1f296e7d.json
#   inflating: dataset/train/9bc72be0.json
#   inflating: dataset/train/c5aa4e80.json
#   inflating: dataset/train/17f78c18.json
#   inflating: dataset/train/ea24c901.json
#   inflating: dataset/train/e941202b.json
#   inflating: dataset/train/ed00536a.json
#   inflating: dataset/train/e549da57.json
#   inflating: dataset/train/37b11036.json
#   inflating: dataset/train/c44d34cc.json
#   inflating: dataset/train/ce542085.json
#   inflating: dataset/train/7c424dfd.json
#   inflating: dataset/train/4d83b2b2.json
#   inflating: dataset/train/89c28b73.json
#   inflating: dataset/train/d2a28e49.json
#   inflating: dataset/train/804abb23.json
#   inflating: dataset/train/fd59f05f.json
#   inflating: dataset/train/658e6ae1.json
#   inflating: dataset/train/e2b9540d.json
#   inflating: dataset/train/d24f5a0a.json
#   inflating: dataset/train/1f63a08c.json
#   inflating: dataset/train/24749087.json
#   inflating: dataset/train/a0447119.json
#   inflating: dataset/train/0d37415e.json
#   inflating: dataset/train/baef75e5.json
#   inflating: dataset/train/b2d97d1c.json
#   inflating: dataset/train/0cc93d48.json
#   inflating: dataset/train/eff38509.json
#   inflating: dataset/train/4d253047.json
#   inflating: dataset/train/bfaefe62.json
#   inflating: dataset/train/091c0f48.json
#   inflating: dataset/train/bed6767e.json
#   inflating: dataset/train/0a368bca.json
#   inflating: dataset/train/ec34a348.json
#   inflating: dataset/train/703ebd79.json
#   inflating: dataset/train/f79faa11.json
#   inflating: dataset/train/465cdb27.json

# %%
# !pip install transformers datasets accelerate peft bitsandbytes trl
# !pip install sentencepiece protobuf
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.56.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.10.1)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (0.17.1)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.47.0-py3-none-manylinux_2_24_x86_64.whl.metadata (11 kB)
# Collecting trl
#   Downloading trl-0.23.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.8.0+cu126)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Downloading bitsandbytes-0.47.0-py3-none-manylinux_2_24_x86_64.whl (61.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 19.2 MB/s eta 0:00:00
# Downloading trl-0.23.0-py3-none-any.whl (564 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.7/564.7 kB 40.0 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes, trl
# Successfully installed bitsandbytes-0.47.0 trl-0.23.0
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (5.29.5)

# %%
# -*- coding: utf-8 -*-
"""
Unified evaluator for Qwen2.5 MCQ SFT (baseline / LoRA)
- Colab-safe (no flash-attn required)
- Supports:
    --model_type baseline | lora
    --mode logits | generate
- Batch inference, JSONL details, accuracy, confusion matrix
"""

import os
import re
import json
import glob
import time
import math
from collections import Counter, defaultdict

import torch
from tqdm import tqdm
from datasets import Dataset

from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig,
)

try:
    from peft import PeftModel
    PEFT_AVAILABLE = True
except ImportError:
    PEFT_AVAILABLE = False


# ---------------------------
# Defaults (edit as needed)
# ---------------------------
DEFAULT_BASE = "Qwen/Qwen2.5-0.5B-Instruct"


def safe_attention_impl():
    """Always return an attention implementation that works on Colab free tier."""
    return "eager"


def build_user_instruction(title, content, question, choices_dict):
    # deterministic A-D order if present
    ordered = []
    for k in ["A", "B", "C", "D"]:
        if k in choices_dict:
            ordered.append(f"{k}: {choices_dict[k]}")
    if not ordered:
        ordered = [f"{k}: {v}" for k, v in choices_dict.items()]

    choices_text = "\n".join(ordered)

    instruction = (
        "Bạn là hệ thống trả lời trắc nghiệm. Hãy đọc văn bản và câu hỏi, "
        "chỉ chọn **một đáp án duy nhất** từ A/B/C/D, không giải thích, không thêm nội dung khác.\n\n"
        f"Văn bản:\nTiêu đề: {title}\n\nNội dung: {content}\n\n"
        f"Câu hỏi:\n{question}\n\n"
        f"Các lựa chọn:\n{choices_text}\n\n"
        "Chỉ trả lời đúng 1 ký tự: A, B, C hoặc D."
    )
    return instruction


def load_json_files(dataset_path):
    files = glob.glob(os.path.join(dataset_path, "*.json"))
    print(f"Found {len(files)} JSON files in '{dataset_path}'")
    items = []
    for p in files:
        try:
            with open(p, "r", encoding="utf-8") as f:
                items.append(json.load(f))
        except Exception as e:
            print(f"Error reading {p}: {e}")
    return items


def prepare_eval_rows(dataset_path):
    """Return a list of dicts: {instruction, label} for MCQ."""
    data_list = load_json_files(dataset_path)
    rows = []
    dropped = 0
    for data in data_list:
        content = data.get("content:") or data.get("content", "")
        title = data.get("title:") or data.get("title", "")
        questions = data.get("questions", [])
        if not content:
            dropped += 1
            continue

        for q in questions:
            question = (q.get("question", "") or "").strip()
            choices = q.get("choices", {}) or {}
            gt = (q.get("correct_answer", "") or "").strip().upper()[:1]
            if gt not in ["A", "B", "C", "D"]:
                continue
            instruction = build_user_instruction(title, content, question, choices)
            rows.append({"instruction": instruction, "label": gt})
    print(f"Prepared {len(rows)} eval rows (dropped {dropped} docs without content).")
    return rows


def load_model_and_tokenizer(
    model_type: str,
    base_model_name: str,
    adapter_path: str = None,
    use_4bit: bool = True,
    bf16: bool = torch.cuda.is_bf16_supported(),
):
    """
    model_type: 'baseline' | 'lora'
    baseline: load base model (optionally 4bit)
    lora:     load base (4bit) + attach LoRA from adapter_path
    """
    if model_type not in ["baseline", "lora"]:
        raise ValueError(f"model_type must be 'baseline' or 'lora', but got '{model_type}'")

    attn_impl = safe_attention_impl()

    # baseline or lora: use 4-bit by default to save VRAM
    bnb = BitsAndBytesConfig(
        load_in_4bit=bool(use_4bit),
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.bfloat16 if bf16 else torch.float16,
        bnb_4bit_use_double_quant=True,
    ) if use_4bit else None

    model = AutoModelForCausalLM.from_pretrained(
        base_model_name,
        device_map="auto",
        torch_dtype=torch.bfloat16 if bf16 else torch.float16,
        attn_implementation=attn_impl,
        trust_remote_code=True,
        quantization_config=bnb if use_4bit else None,
    )
    tok_src = base_model_name

    if model_type == "lora":
        if not PEFT_AVAILABLE:
            raise RuntimeError("peft is not installed. Please run: pip install peft")
        if not adapter_path:
            raise ValueError("--adapter_path is required for model_type=lora")
        print(f"Loading LoRA adapter from: {adapter_path}")
        model = PeftModel.from_pretrained(model, adapter_path)

    tokenizer = AutoTokenizer.from_pretrained(tok_src, trust_remote_code=True)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token
    print("Loaded model config from:", getattr(model.config, "_name_or_path", None))

    # If using LoRA, print details
    if model_type == 'lora' and isinstance(model, PeftModel):
        print("PEFT adapter attached. Active adapters:", getattr(model, "active_adapters", None))
        model.print_trainable_parameters()

    model.eval()
    return model, tokenizer


def to_chat_prompt(tokenizer, instruction: str):
    messages = [
        {"role": "system", "content": "Bạn là hệ thống trả lời trắc nghiệm. Chỉ xuất duy nhất 1 ký tự A/B/C/D."},
        {"role": "user", "content": instruction},
    ]
    return tokenizer.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=True
    )


def parse_generated(text: str):
    # Robust A-D extraction
    m = re.search(r"(?:Đáp án|Trả lời|Câu\s*trả\s*lời)\s*:?\s*([A-D])", text, flags=re.IGNORECASE)
    if m: return m.group(1).upper()
    m = re.search(r"\b([A-D])[:.]?\b", text) # Make colon/period optional
    if m: return m.group(1).upper()
    m = re.search(r"\b([A-D])\b", text)
    if m: return m.group(1).upper()
    return None


def get_letter_token_ids(tokenizer):
    """Map letters to token IDs; if any letter is not single-token, return None to disable logits mode."""
    letter_ids = {}
    for ch in ["A", "B", "C", "D"]:
        ids = tokenizer(ch, add_special_tokens=False).input_ids
        if len(ids) != 1:
            print(f"Warning: Letter '{ch}' is not a single token. Logits mode might be inaccurate. Fallback to generate recommended.")
            return None
        letter_ids[ch] = ids[0]
    return letter_ids


def eval_logits_mode(model, tokenizer, prompts, labels, max_length):
    """
    One forward pass: pick next-token argmax over {A,B,C,D}.
    Fast & stable if letters are single-token.
    """
    letter_map = get_letter_token_ids(tokenizer)
    if letter_map is None:
        return None  # signal to caller to fall back to generate

    # Tokenize batch
    enc = tokenizer(
        prompts, return_tensors="pt", padding=True, truncation=True, max_length=max_length
    ).to(model.device)

    with torch.no_grad():
        out = model(**enc)
        # logits shape: [B, T, V]; focus on last valid token per item
        logits = out.logits
        # gather last non-pad position for each sequence
        last_pos = enc.attention_mask.sum(dim=1) - 1
        batch_idx = torch.arange(logits.size(0), device=logits.device)
        next_logits = logits[batch_idx, last_pos, :]

        # score only {A,B,C,D}
        cand_ids = torch.tensor(list(letter_map.values()), device=logits.device)
        cand_logits = next_logits[:, cand_ids]
        pred_idx = cand_logits.argmax(dim=1)

        idx2letter = list(letter_map.keys())
        preds = [idx2letter[i.item()] for i in pred_idx]

    details = []
    correct = 0
    for p, g in zip(preds, labels):
        ok = (p == g)
        correct += int(ok)
        details.append({"pred": p, "label": g, "is_correct": ok})
    return details, correct


def eval_generate_mode(model, tokenizer, prompts, labels, max_length):
    """Greedy short generation; parse first A–D found."""
    inputs = tokenizer(
        prompts, return_tensors="pt", padding=True, truncation=True, max_length=max_length
    ).to(model.device)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=4, # A bit more generous for safety
            temperature=0.0,
            do_sample=False,
            eos_token_id=tokenizer.eos_token_id,
            pad_token_id=tokenizer.eos_token_id,
        )

    gens = tokenizer.batch_decode(outputs[:, inputs.input_ids.shape[1]:], skip_special_tokens=True)
    details = []
    correct = 0
    for g, lab in zip(gens, labels):
        pred = parse_generated(g) or "E"  # Use 'E' (Error) for fallback
        ok = (pred == lab)
        correct += int(ok)
        details.append({"pred": pred, "label": lab, "raw": g.strip(), "is_correct": ok})
    return details, correct


def run_eval(
    model,
    tokenizer,
    rows,
    batch_size=16,
    max_length=4096,
    mode="logits",
    out_jsonl="eval_details.jsonl",
):
    total = len(rows)
    correct = 0
    all_details = []
    start = time.time()

    # Build prompts in advance (chat template)
    prompts = [to_chat_prompt(tokenizer, r["instruction"]) for r in rows]
    labels = [r["label"] for r in rows]

    # Iterate in batches
    for i in tqdm(range(0, total, batch_size), desc="Evaluating"):
        ps = prompts[i:i+batch_size]
        ls = labels[i:i+batch_size]
        details, corr = None, 0

        if mode == "logits":
            res = eval_logits_mode(model, tokenizer, ps, ls, max_length)
            if res is None:
                print("Logits mode failed (multi-token letters), falling back to generate mode.")
                mode = "generate" # Switch mode for subsequent batches

        if mode == "generate":
             res = eval_generate_mode(model, tokenizer, ps, ls, max_length)

        details, corr = res
        all_details.extend(details)
        correct += corr

    elapsed = time.time() - start
    acc = 100.0 * correct / total if total else 0.0

    # Compute confusion & distribution
    cm = defaultdict(lambda: Counter())
    dist = Counter()
    for d in all_details:
        dist[d["pred"]] += 1
        cm[d["label"]][d["pred"]] += 1

    # Save JSONL (one line per item)
    with open(out_jsonl, "w", encoding="utf-8") as f:
        for d in all_details:
            f.write(json.dumps(d, ensure_ascii=False) + "\n")

    # Pretty print summary
    print("\n=== EVAL SUMMARY ===")
    print(f"Total items: {total}")
    print(f"Correct:     {correct}")
    print(f"Accuracy:    {acc:.2f}%")
    print(f"Time:        {elapsed:.2f}s")
    print(f"Items/sec:   {total/elapsed:.2f}")
    print(f"Output saved to: {out_jsonl}")
    print("\nPredicted distribution:", dict(dist))
    print("\nConfusion matrix (rows=label, cols=pred):")
    letters = sorted(list(set(cm.keys()) | set(dist.keys())))
    header = "     " + "  ".join([f"{c:>5}" for c in letters])
    print(header)
    for lab in letters:
        if lab not in cm: continue
        row = [cm[lab][p] for p in letters]
        print(f"{lab:>3}: " + "  ".join([f"{n:>5}" for n in row]))

    return {
        "total": total,
        "correct": correct,
        "accuracy": acc,
        "time_sec": elapsed,
        "items_per_sec": total/elapsed if elapsed > 0 else 0.0,
        "pred_dist": dict(dist),
        "confusion": {lab: dict(cm[lab]) for lab in cm},
    }


# ===================================================================================
# MODIFIED FOR COLAB: Direct function call instead of argparse
# ===================================================================================

def run_colab_evaluation(
    eval_dataset_path: str,
    model_type: str = "baseline",
    base_model: str = DEFAULT_BASE,
    adapter_path: str = None,
    batch_size: int = 16,
    max_length: int = 1024,
    mode: str = "logits",
    use_4bit: bool = True,
    output_jsonl: str = "eval_details.jsonl"
):
    """
    Main function to run the entire evaluation pipeline for baseline or LoRA models.
    Call this function directly from your Colab notebook.
    """
    # Prepare data
    rows = prepare_eval_rows(eval_dataset_path)
    if not rows:
        print("No eval data found. Exiting.")
        return

    # Load model/tokenizer
    bf16 = torch.cuda.is_bf16_supported()
    model, tokenizer = load_model_and_tokenizer(
        model_type=model_type,
        base_model_name=base_model,
        adapter_path=adapter_path,
        use_4bit=use_4bit,
        bf16=bf16,
    )

    # Run eval
    run_eval(
        model=model,
        tokenizer=tokenizer,
        rows=rows,
        batch_size=batch_size,
        max_length=max_length,
        mode=mode,
        out_jsonl=output_jsonl,
    )


# ===================================================================================
# EXAMPLE USAGE IN COLAB
# ===================================================================================
if __name__ == "__main__":
    # This block will run if you execute the script directly.
    # In a Colab notebook, you can copy, paste, and modify these lines into a cell.

    # --- STEP 1: UPLOAD YOUR DATA ---
    # Make sure your evaluation JSON files are in a folder.
    # For example, create a folder named 'my_eval_data' in your Colab environment
    # and upload your files there.

    # --- STEP 2: CONFIGURE AND RUN ---
    # Choose the configuration that matches your model.

    # === EXAMPLE 1: Evaluating the baseline Qwen2.5 model ===
    print("--- Running evaluation for BASELINE model ---")
    run_colab_evaluation(
        eval_dataset_path="/content/dataset/public",  # <-- IMPORTANT: Change to your data folder
        model_type="baseline",
        base_model="Qwen/Qwen2.5-0.5B-Instruct",
        use_4bit=True, # Use 4-bit quantization to save memory
        batch_size=8,
        mode="logits", # 'logits' is faster, 'generate' is more robust
        output_jsonl="baseline_eval_details.jsonl"
    )

    # === EXAMPLE 2: Evaluating a LoRA model ===
    # print("\n\n--- Running evaluation for LoRA model ---")
    # run_colab_evaluation(
    #     eval_dataset_path="/content/dataset/public",    # <-- IMPORTANT: Change to your data folder
    #     model_type="lora",
    #     base_model="Qwen/Qwen2.5-0.5B-Instruct", # The base model used for training the LoRA
    #     adapter_path="/content/qwen_legal_lora_sft", # <-- IMPORTANT: Change to your LoRA adapter folder
    #     use_4bit=True,
    #     batch_size=8,
    #     mode="logits",
    #     output_jsonl="lora_eval_details.jsonl"
    # )

    print("\nScript loaded. To run an evaluation in a Colab notebook,")
    print("copy one of the example blocks above into a new cell,")
    print("modify the paths, and run the cell.")
# Out:
# --- Running evaluation for MERGED model ---
# Found 200 JSON files in '/content/dataset/public'
# Prepared 597 eval rows (dropped 1 docs without content).
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3736139125.py in <cell line: 0>()
#     450     # === EXAMPLE 3: Evaluating a merged (dense) model ===
#     451     print("\n\n--- Running evaluation for MERGED model ---")
# --> 452     run_colab_evaluation(
#     453         eval_dataset_path="/content/dataset/public",  # <-- IMPORTANT: Change to your data folder
#     454         model_type="merged",
#
# /tmp/ipython-input-3736139125.py in run_colab_evaluation(eval_dataset_path, model_type, base_model, adapter_path, merged_path, batch_size, max_length, mode, use_4bit, output_jsonl)
#     387     # Load model/tokenizer
#     388     bf16 = torch.cuda.is_bf16_supported()
# --> 389     model, tokenizer = load_model_and_tokenizer(
#     390         model_type=model_type,
#     391         base_model_name=base_model,
#
# /tmp/ipython-input-3736139125.py in load_model_and_tokenizer(model_type, base_model_name, adapter_path, merged_path, use_4bit, bf16)
#     162             model = PeftModel.from_pretrained(model, adapter_path)
#     163
# --> 164     tokenizer = AutoTokenizer.from_pretrained(tok_src, trust_remote_code=True)
#     165     if tokenizer.pad_token is None:
#     166         tokenizer.pad_token = tokenizer.eos_token
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/tokenization_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#    1142
#    1143             if tokenizer_class_fast and (use_fast or tokenizer_class_py is None):
# -> 1144                 return tokenizer_class_fast.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#    1145             else:
#    1146                 if tokenizer_class_py is not None:
#
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py in from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    2068                 logger.info(f"loading file {file_path} from cache at {resolved_vocab_files[file_id]}")
#    2069
# -> 2070         return cls._from_pretrained(
#    2071             resolved_vocab_files,
#    2072             pretrained_model_name_or_path,
#
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py in _from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, token, cache_dir, local_files_only, _commit_hash, _is_local, trust_remote_code, *init_inputs, **kwargs)
#    2106         # loaded directly from the GGUF file.
#    2107         if (from_slow or not has_tokenizer_file) and cls.slow_tokenizer_class is not None and not gguf_file:
# -> 2108             slow_tokenizer = (cls.slow_tokenizer_class)._from_pretrained(
#    2109                 copy.deepcopy(resolved_vocab_files),
#    2110                 pretrained_model_name_or_path,
#
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py in _from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, token, cache_dir, local_files_only, _commit_hash, _is_local, trust_remote_code, *init_inputs, **kwargs)
#    2314         # Instantiate the tokenizer.
#    2315         try:
# -> 2316             tokenizer = cls(*init_inputs, **init_kwargs)
#    2317         except import_protobuf_decode_error():
#    2318             logger.info(
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen2/tokenization_qwen2.py in __init__(self, vocab_file, merges_file, errors, unk_token, bos_token, eos_token, pad_token, clean_up_tokenization_spaces, split_special_tokens, **kwargs)
#     170         )
#     171
# --> 172         with open(vocab_file, encoding="utf-8") as vocab_handle:
#     173             self.encoder = json.load(vocab_handle)
#     174         self.decoder = {v: k for k, v in self.encoder.items()}
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %%
import os
os.environ["WANDB_DISABLED"] = "true"
os.environ["WANDB_MODE"] = "disabled"
import re
import glob
import json
import random
import torch
import pandas as pd
from datasets import Dataset
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig,
)
from peft import (
    LoraConfig,
    get_peft_model,
    TaskType,
    prepare_model_for_kbit_training,
)
from trl import SFTTrainer, SFTConfig
from sklearn.model_selection import train_test_split

# -----------------------------
# Device / backend preferences
# -----------------------------
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")

torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.allow_tf32 = True

# -----------------------------
# Configuration
# -----------------------------
class Config:
    # Base model
    model_name = "Qwen/Qwen2.5-0.5B-Instruct"

    # I/O
    dataset_path = "/content/dataset/train"
    output_dir = "./qwen_legal_lora_sft"

    # Sequence & batching
    max_seq_length = 1024          # raise if VRAM allows; 1024 if tight
    per_device_train_batch_size = 2
    gradient_accumulation_steps = 4

    # Steps / schedule
    max_steps = 70                # quick run; raise for better quality
    warmup_ratio = 0.06
    learning_rate = 2e-4
    weight_decay = 0.01
    lr_scheduler_type = "cosine"
    logging_steps = 10
    max_grad_norm = 0.3
    seed = 3407

    # Precision
    fp16 = not torch.cuda.is_bf16_supported()
    bf16 = torch.cuda.is_bf16_supported()

    # Data split
    test_size = 0.1

    # LoRA
    lora_r = 32
    lora_alpha = 16
    lora_dropout = 0.05
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj"
    ]

    # Optimizer (bitsandbytes)
    optim = "adamw_bnb_8bit"

random.seed(Config.seed)

# -----------------------------
# Data loading & preprocessing
# -----------------------------
def load_json_files(dataset_path):
    """Load all JSON files from the dataset directory."""
    json_files = glob.glob(os.path.join(dataset_path, "*.json"))
    print(f"Found {len(json_files)} JSON files")

    all_data = []
    for file_path in json_files:
        try:
            with open(file_path, "r", encoding="utf-8") as f:
                data = json.load(f)
                all_data.append(data)
        except Exception as e:
            print(f"Error loading {file_path}: {e}")
    return all_data

def build_text_sample(tokenizer, instruction, correct_answer):
    """
    Create a single training string using the tokenizer's chat template.
    We supervise on a single letter A/B/C/D (+ EOS).
    """
    # System prompt: keep it short and strict
    system_msg = "Bạn là hệ thống trả lời trắc nghiệm. Chỉ xuất duy nhất 1 ký tự A/B/C/D."

    messages = [
        {"role": "system", "content": system_msg},
        {"role": "user", "content": instruction},
        {"role": "assistant", "content": correct_answer.strip()[:1]},  # "A"/"B"/"C"/"D"
    ]
    # Returns the whole conversation with assistant turn included.
    # For SFT, that's perfect because TRL will compute loss on assistant tokens.
    chat_str = tokenizer.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=False
    )
    # Ensure EOS at the end for stable termination
    if not chat_str.endswith(tokenizer.eos_token or ""):
        chat_str += (tokenizer.eos_token or "")
    return chat_str

def create_training_samples(data_list, tokenizer):
    """Convert JSON data to training samples, handling multiple key formats."""
    samples = []
    dropped = 0

    for data in data_list:
        content = data.get("content:") or data.get("content", "")
        title = data.get("title:") or data.get("title", "")
        questions = data.get("questions", [])

        if not content:
            dropped += 1
            print("\n--- BỎ QUA: Thiếu content ---")
            problematic_data = {k: v for k, v in data.items() if k not in ["content", "content:"]}
            print(problematic_data)
            continue

        context = f"Tiêu đề: {title}\n\nNội dung: {content}"

        for q in questions:
            question = q.get("question", "").strip()
            choices = q.get("choices", {})
            correct_answer = (q.get("correct_answer", "") or "").strip()[:1].upper()

            if correct_answer not in ["A", "B", "C", "D"]:
                continue

            # Present choices in a deterministic order A-D if present
            ordered = []
            for key in ["A", "B", "C", "D"]:
                if key in choices:
                    ordered.append(f"{key}: {choices[key]}")
            choices_text = "\n".join(ordered) if ordered else "\n".join([f"{k}: {v}" for k, v in choices.items()])

            instruction = (
                "Bạn là hệ thống trả lời trắc nghiệm. Hãy đọc văn bản và câu hỏi, "
                "chỉ chọn **một đáp án duy nhất** từ A/B/C/D, không giải thích, không thêm nội dung khác.\n\n"
                f"Văn bản:\n{context}\n\n"
                f"Câu hỏi:\n{question}\n\n"
                f"Các lựa chọn:\n{choices_text}\n\n"
                "Chỉ trả lời đúng 1 ký tự: A, B, C hoặc D."
            )

            text = build_text_sample(tokenizer, instruction, correct_answer)
            samples.append({"text": text})

    print(f"Created {len(samples)} samples (dropped {dropped} docs without content).")
    return samples

def prepare_dataset(dataset_path, tokenizer, test_size=0.1):
    """Prepare dataset: load → build → dedup → split → HuggingFace Dataset."""
    data_list = load_json_files(dataset_path)
    print(f"Loaded {len(data_list)} documents")

    samples = create_training_samples(data_list, tokenizer)
    df = pd.DataFrame(samples).drop_duplicates(subset=["text"]).reset_index(drop=True)
    train_df, val_df = train_test_split(
        df, test_size=test_size, random_state=Config.seed, shuffle=True
    )
    train_ds = Dataset.from_pandas(train_df)
    val_ds = Dataset.from_pandas(val_df)
    print(f"Train: {len(train_ds)} | Validation: {len(val_ds)}")
    return {"train": train_ds, "eval": val_ds}

# -----------------------------
# Model / Tokenizer setup
# -----------------------------
def setup_model_and_tokenizer():
    """Setup model & tokenizer with 4-bit QLoRA and fast attention."""
    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.bfloat16 if Config.bf16 else torch.float16,
        bnb_4bit_use_double_quant=True,
    )

    tokenizer = AutoTokenizer.from_pretrained(Config.model_name, trust_remote_code=True)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    # Try FlashAttention-2 if available; silently fall back otherwise
    attn_impl = "eager"   # or just remove attn_implementation argument

    model = AutoModelForCausalLM.from_pretrained(
        Config.model_name,
        quantization_config=bnb_config,
        device_map="auto",
        torch_dtype=torch.bfloat16 if Config.bf16 else torch.float16,
        attn_implementation=attn_impl,
        trust_remote_code=True,
    )

    # Gradient checkpointing + input grads
    model.gradient_checkpointing_enable(gradient_checkpointing_kwargs={"use_reentrant": False})
    model = prepare_model_for_kbit_training(model, use_gradient_checkpointing=True)
    try:
        model.enable_input_require_grads()
    except Exception:
        pass

    return model, tokenizer

def setup_lora_config():
    """LoRA configuration tuned for small Qwen2.5."""
    return LoraConfig(
        r=Config.lora_r,
        lora_alpha=Config.lora_alpha,
        target_modules=Config.target_modules,
        lora_dropout=Config.lora_dropout,
        bias="none",
        task_type=TaskType.CAUSAL_LM,
    )

# -----------------------------
# Training
# -----------------------------
def train_model():
    print("Loading model & tokenizer...")
    model, tokenizer = setup_model_and_tokenizer()

    print("Preparing dataset...")
    dataset = prepare_dataset(Config.dataset_path, tokenizer, Config.test_size)

    print("Setting up LoRA...")
    lora_config = setup_lora_config()
    model = get_peft_model(model, lora_config)
    model.print_trainable_parameters()

    print("Configuring SFT...")
    sft_config = SFTConfig(
        output_dir=Config.output_dir,
        per_device_train_batch_size=Config.per_device_train_batch_size,
        gradient_accumulation_steps=Config.gradient_accumulation_steps,
        max_steps=Config.max_steps,
        learning_rate=Config.learning_rate,
        fp16=Config.fp16,
        bf16=Config.bf16,
        logging_steps=Config.logging_steps,
        optim=Config.optim,                   # adamw_bnb_8bit
        weight_decay=Config.weight_decay,
        lr_scheduler_type=Config.lr_scheduler_type,  # cosine
        warmup_ratio=Config.warmup_ratio,
        max_grad_norm=Config.max_grad_norm,
        seed=Config.seed,
        dataset_text_field="text",
        packing=True,                         # big speedup for short turns
        save_safetensors=True,
        eval_strategy="steps",
        eval_steps=50,                        # quick feedback during short runs
        save_steps=100,
        logging_first_step=True,
    )

    print("Initializing trainer...")
    trainer = SFTTrainer(
        model=model,
        args=sft_config,
        train_dataset=dataset["train"],
        eval_dataset=dataset["eval"],
        processing_class=tokenizer,
    )

    print("Starting training...")
    trainer.train()

    print("Saving model & tokenizer...")
    trainer.save_model()
    tokenizer.save_pretrained(Config.output_dir)

    return tokenizer, model

# -----------------------------
# Main
# -----------------------------
if __name__ == "__main__":
    print("Ensure your dataset is uploaded to /content/dataset/train")
    tokenizer, model = train_model()
# Out:
# CUDA available: True
# GPU: Tesla T4
# Memory: 15.8 GB
# Ensure your dataset is uploaded to /content/dataset/train
# Loading model & tokenizer...
# Preparing dataset...
# Found 1500 JSON files
# Loaded 1500 documents
#
# --- BỎ QUA: Thiếu content ---
# {'url': 'https://kenh14.vn/loai-cay-ty-do-giup-viet-nam-tro-thanh-ong-trum-xuat-khau-dung-thu-2-the-gioi-nang-suat-dan-dau-toan-cau-tinh-nao-trong-nhieu-nhat-215250130130240016.chn', 'title': '', 'metadata': [['https://kenh14cdn.com/203336854389633024/2025/1/30/cafe-thumb-1738216786511-17382167873341433530892.jpg', "Loại cây tỷ đô giúp Việt Nam trở thành 'ông trùm' xuất khẩu đứng thứ 2 thế giới: Năng suất dẫn đầu toàn cầu, tỉnh nào trồng nhiều nhất?- Ảnh 1."], ['https://kenh14cdn.com/203336854389633024/2025/1/30/cafe-1-1738216788125-17382167882951621571710.jpg', "Loại cây tỷ đô giúp Việt Nam trở thành 'ông trùm' xuất khẩu đứng thứ 2 thế giới: Năng suất dẫn đầu toàn cầu, tỉnh nào trồng nhiều nhất?- Ảnh 2."]]}
#
# --- BỎ QUA: Thiếu content ---
# {'url': 'https://kenh14.vn/kriss-ngo-producer-dung-sau-thanh-cong-cua-trong-com-hi-vong-toi-co-the-gop-phan-nho-trong-gdp-xuat-khau-van-hoa-215250130155009374.chn', 'title': '', 'metadata': [['https://kenh14cdn.com/203336854389633024/2025/1/30/ava-ngang-1738051680912590966332-1738226738501-173822673886655049461.jpg', 'Kriss Ngo - producer đứng sau thành công của Trống Cơm: '], ['https://kenh14cdn.com/203336854389633024/2025/1/30/1-1738051681591460132522-1738226740041-1738226740412365090823.jpg', 'Kriss Ngo - producer đứng sau thành công của Trống Cơm: '], ['https://kenh14cdn.com/203336854389633024/2025/1/30/k14-13-17380516803741899411192-1738226741579-1738226741766283979244.jpg', 'Kriss Ngo - producer đứng sau thành công của Trống Cơm: '], ['https://kenh14cdn.com/203336854389633024/2025/1/30/2-17380516815742007250041-1738226743482-17382267438812027598182.jpg', 'Kriss Ngo - producer đứng sau thành công của Trống Cơm: '], ['https://kenh14cdn.com/203336854389633024/2025/1/30/3-17380516815551996325452-1738226744858-1738226745104180238018.jpg', 'Kriss Ngo - producer đứng sau thành công của Trống Cơm: '], ['https://kenh14cdn.com/203336854389633024/2025/1/30/4-1738051681397170921778-1738226746293-17382267466951877223558.jpg', 'Kriss Ngo - producer đứng sau thành công của Trống Cơm: '], ['https://kenh14cdn.com/203336854389633024/2025/1/30/5-173805168110427739658-1738226747624-17382267481031730478919.jpg', 'Kriss Ngo - producer đứng sau thành công của Trống Cơm: '], ['https://kenh14cdn.com/203336854389633024/2025/1/30/k14-18-1738051680617247874201-1738226749114-17382267496451850331922.jpg', 'Kriss Ngo - producer đứng sau thành công của Trống Cơm: '], ['https://kenh14cdn.com/203336854389633024/2025/1/30/6-1738051681228361578484-1738226752092-1738226752469943963767.jpg', 'Kriss Ngo - producer đứng sau thành công của Trống Cơm: '], ['https://kenh14cdn.com/203336854389633024/2025/1/30/7-1738051681163572763096-1738226753365-1738226753523834725244.jpg', 'Kriss Ngo - producer đứng sau thành công của Trống Cơm: ']]}
#
# --- BỎ QUA: Thiếu content ---
# {'url': 'https://kenh14.vn/lan-song-am-nhac-thai-lan-lan-toa-ra-the-gioi-215250202175223071.chn', 'title': '', 'metadata': []}
# Created 4491 samples (dropped 3 docs without content).
# Train: 4041 | Validation: 450
# Setting up LoRA...
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# WARNING:trl.trainer.sft_trainer:Padding-free training is enabled, but the attention implementation is not set to 'flash_attention_2'. Padding-free training flattens batches into a single sequence, and 'flash_attention_2' is the only known attention mechanism that reliably supports this. Using other implementations may lead to unexpected behavior. To ensure compatibility, set `attn_implementation='flash_attention_2'` in the model configuration, or verify that your attention mechanism can handle flattened sequences.
# WARNING:trl.trainer.sft_trainer:You are using packing, but the attention implementation is not set to 'flash_attention_2' or 'kernels-community/vllm-flash-attn3'. Packing flattens batches into a single sequence, and Flash Attention is the only known attention mechanisms that reliably support this. Using other implementations may lead to cross-contamination between batches. To avoid this, either disable packing by setting `packing=False`, or set `attn_implementation='flash_attention_2'` or `attn_implementation='kernels-community/vllm-flash-attn3'` in the model configuration.
# trainable params: 17,596,416 || all params: 511,629,184 || trainable%: 3.4393
# Configuring SFT...
# Initializing trainer...
# Adding EOS to train dataset:   0%|          | 0/4041 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/4041 [00:00<?, ? examples/s]
# Packing train dataset:   0%|          | 0/4041 [00:00<?, ? examples/s]
# Adding EOS to eval dataset:   0%|          | 0/450 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/450 [00:00<?, ? examples/s]
# Packing eval dataset:   0%|          | 0/450 [00:00<?, ? examples/s]
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
# Starting training...
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:929: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='70' max='70' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [70/70 26:15, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Entropy</th>
#       <th>Num Tokens</th>
#       <th>Mean Token Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>2.578300</td>
#       <td>2.299219</td>
#       <td>2.194419</td>
#       <td>384856.000000</td>
#       <td>0.544540</td>
#     </tr>
#   </tbody>
# </table><p>
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Saving model & tokenizer...
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# Caching is incompatible with gradient checkpointing in Qwen2DecoderLayer. Setting `past_key_values=None`.
# Testing the fine-tuned model (greedy single-letter)...
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:929: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/utils/checkpoint.py:85: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-4231939050.py in <cell line: 0>()
#     428     print("\nTesting the fine-tuned model (greedy single-letter)...")
#     429     test_instruction = build_user_instruction_example()
# --> 430     letter, raw = generate_letter(model, tokenizer, test_instruction)
#     431     print("\n--- Generated ---")
#     432     print("Letter:", letter)
#
# /tmp/ipython-input-4231939050.py in generate_letter(model, tokenizer, user_instruction)
#     330
#     331     with torch.no_grad():
# --> 332         outputs = model.generate(
#     333             **inputs,
#     334             max_new_tokens=2,            # single token + eos
#
# /usr/local/lib/python3.12/dist-packages/peft/peft_model.py in generate(self, *args, **kwargs)
#    1971                 with self._enable_peft_forward_hooks(*args, **kwargs):
#    1972                     kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 1973                     outputs = self.base_model.generate(*args, **kwargs)
#    1974             else:
#    1975                 outputs = self.base_model.generate(**kwargs)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2537         elif generation_mode in (GenerationMode.SAMPLE, GenerationMode.GREEDY_SEARCH):
#    2538             # 11. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2539             result = self._sample(
#    2540                 input_ids,
#    2541                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2865
#    2866             if is_prefill:
# -> 2867                 outputs = self(**model_inputs, return_dict=True)
#    2868                 is_prefill = False
#    2869             else:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     938         if return_dict_passed is not None:
#     939             return_dict = return_dict_passed
# --> 940         output = func(self, *args, **kwargs)
#     941         if not return_dict and not isinstance(output, tuple):
#     942             output = output.to_tuple()
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen2/modeling_qwen2.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, cache_position, logits_to_keep, **kwargs)
#     461         # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#     462         slice_indices = slice(-logits_to_keep, None) if isinstance(logits_to_keep, int) else logits_to_keep
# --> 463         logits = self.lm_head(hidden_states[:, slice_indices, :])
#     464
#     465         loss = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# RuntimeError: expected scalar type Float but found BFloat16

# %%
from google.colab import drive
drive.mount('/content/drive')

# !mkdir -p /content/drive/MyDrive/qwen_runs
# !cp -r ./qwen_legal_lora_sft /content/drive/MyDrive/qwen_runs/
# !cp /content/lora_eval_details.jsonl /content/drive/MyDrive/qwen_runs/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# cp: cannot stat './qwen_legal_lora_sft_merged': No such file or directory
